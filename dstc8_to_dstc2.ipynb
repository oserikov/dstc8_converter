# %% [markdown]
# <a href="https://colab.research.google.com/github/oserikov/dstc8_dstc2_converter/blob/master/dstc8_to_dstc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# An example of deeppavlov go-bot training on the dstc8 subsets using the dstc8 to dstc2 data converter ( github.com/oserikov/dstc8_dstc2_converter )
#
# see the [README](https://github.com/oserikov/dstc8_dstc2_converter/blob/master/README.md) for details on the converters used here.

# %%
import os
from getpass import getpass
import urllib

# %%
# !pip install -q deeppavlov
# !git clone https://github.com/google-research-datasets/dstc8-schema-guided-dialogue.git
# !git clone https://github.com/oserikov/dstc8_dstc2_converter.git
# Out:
#      |████████████████████████████████| 757kB 4.8MB/s
#      |████████████████████████████████| 2.9MB 51.6MB/s
#      |████████████████████████████████| 51kB 7.4MB/s
#      |████████████████████████████████| 61kB 8.2MB/s
#      |████████████████████████████████| 51kB 7.5MB/s
#      |████████████████████████████████| 61kB 9.3MB/s
#      |████████████████████████████████| 51kB 7.1MB/s
#      |████████████████████████████████| 71kB 8.5MB/s
#      |████████████████████████████████| 6.7MB 37.7MB/s
#      |████████████████████████████████| 7.3MB 48.3MB/s
#      |████████████████████████████████| 20.1MB 184kB/s
#      |████████████████████████████████| 8.0MB 32.0MB/s
#      |████████████████████████████████| 51kB 8.2MB/s
#      |████████████████████████████████| 61kB 9.5MB/s
#      |████████████████████████████████| 1.5MB 58.1MB/s
#      |████████████████████████████████| 2.1MB 34.9MB/s
#      |████████████████████████████████| 7.1MB 21.6MB/s
# ...

# %%
# set the proper value of the path-to-the-dataset constant
# !sed -i -e "s|^DSTC8_REPO_PATH.*$|DSTC8_REPO_PATH = \"/content/dstc8-schema-guided-dialogue\"|" dstc8_dstc2_converter/constants.py

# %%
# %cd dstc8_dstc2_converter/
# Out:
# /content/dstc8_dstc2_converter

# %% [markdown]
# The conversion repo contains 4 different converters, `exp1...` is the slowest one and is executed after all the others in this tutorial.

# %% [markdown]
# converter 2

# %%
# !python3 exp1_conversion.py
# Out:
# 2020-03-23 20:12:18.984 WARNING in 'deeppavlov.core.models.serializable'['serializable'] at line 49: No load path is set for Sqlite3Database in 'infer' mode. Using save path instead
# 2020-03-23 20:12:18.984 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 70: Initializing empty database on /content/dstc8_dstc2_converter/my_bot/db.sqlite.
# 2020-03-23 20:12:18.993 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 130: Created table with keys {'area': 'text'}.
# 2020-03-23 20:12:19.120 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-trn.json]
# 2020-03-23 20:12:19.145 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-val.json]
# ...

# %% [markdown]
# converter 3

# %%
# !python3 exp2_conversion.py
# Out:
# 2020-03-23 20:15:00.484 WARNING in 'deeppavlov.core.models.serializable'['serializable'] at line 49: No load path is set for Sqlite3Database in 'infer' mode. Using save path instead
# 2020-03-23 20:15:00.484 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 70: Initializing empty database on /content/dstc8_dstc2_converter/my_bot/db.sqlite.
# 2020-03-23 20:15:00.495 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 130: Created table with keys {'pets_allowed': 'text'}.
# 2020-03-23 20:15:00.620 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-trn.json]
# 2020-03-23 20:15:00.642 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-val.json]
# ...

# %% [markdown]
# converter 4

# %%
# !python3 exp3_conversion.py
# Out:
# 2020-03-23 20:17:37.124 WARNING in 'deeppavlov.core.models.serializable'['serializable'] at line 49: No load path is set for Sqlite3Database in 'infer' mode. Using save path instead
# 2020-03-23 20:17:37.125 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 70: Initializing empty database on /content/dstc8_dstc2_converter/my_bot/db.sqlite.
# 2020-03-23 20:17:37.134 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 130: Created table with keys {'property_name': 'text'}.
# 2020-03-23 20:17:37.263 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-trn.json]
# 2020-03-23 20:17:37.287 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-val.json]
# ...

# %% [markdown]
# converter 1 (really slow & naive)

# %%
# !python3 naive_conversion.py
# Out:
# 2020-03-23 20:20:16.265 WARNING in 'deeppavlov.core.models.serializable'['serializable'] at line 49: No load path is set for Sqlite3Database in 'infer' mode. Using save path instead
# 2020-03-23 20:20:16.265 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 70: Initializing empty database on /content/dstc8_dstc2_converter/my_bot/db.sqlite.
# 2020-03-23 20:20:16.280 INFO in 'deeppavlov.core.data.sqlite_database'['sqlite_database'] at line 130: Created table with keys {'area': 'text'}.
# 2020-03-23 20:20:16.410 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-trn.json]
# 2020-03-23 20:20:16.435 INFO in 'deeppavlov.dataset_readers.dstc2_reader'['dstc2_reader'] at line 290: [loading dialogs from /content/dstc8_dstc2_converter/my_data/simple-dstc2-val.json]
# ...
